# %% [markdown]
# # Devasy Patel
# # Practical 6
# # Deep Learning
# ## Tasks
# - Use any package (NLTK,Sklearn, Scikit) to implement Sentiment analysis for any Review data.  (Movie, product, sevrices)

# %%
import pandas as pd
df= pd.read_csv('C:/Users/Owner/Desktop/College/SEM6/NLP/train.csv')
df
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                                     text           Sentiment
# ...

# %%
import numpy as np

df['text'] = df['text'].str.replace('[^\w\s]','')

# import count vectorizer from sklearn
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()

# convert text data into term-frequency matrix
X_train_tf = count_vect.fit_transform(df['text'])
X_train_tf.shape
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_6764\523371719.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['text'] = df['text'].str.replace('[^\w\s]','')
# (41157, 84506)

# %%
y = (df['Sentiment']).values
 


from sklearn.model_selection import train_test_split
# import logistic regression from sklearn
from sklearn.linear_model import LogisticRegression

# split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_train_tf, y, test_size=0.3, random_state=0)

# train a logistic regression model on the training set

logreg = LogisticRegression()
logreg.fit(X_train, y_train)

# make class predictions for the testing set
y_pred_class = logreg.predict(X_test)
 
# calculate accuracy
from sklearn import metrics
print(metrics.accuracy_score(y_test, y_pred_class))
# Out:
# 0.6026886945254292
# c:\Users\Owner\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
